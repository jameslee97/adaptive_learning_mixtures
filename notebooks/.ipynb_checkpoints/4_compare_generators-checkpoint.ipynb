# %%
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns; sns.set()
# %matplotlib inline

import keras
from keras.models import Sequential, Model
from keras.layers import Dense
from keras.optimizers import Adam
import salty
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from sklearn.model_selection import train_test_split
from random import shuffle
import pandas as pd
import random
# Out:
# /home/wesleybeckner/anaconda3/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras import backend as K
from keras.objectives import binary_crossentropy #objs or losses
from keras.models import Model
from keras.layers import Input, Dense, Lambda
from keras.layers.core import Dense, Activation, Flatten, RepeatVector
from keras.layers.wrappers import TimeDistributed
from keras.layers.recurrent import GRU
from keras.layers.convolutional import Convolution1D

# %%
def Encoder(x, latent_rep_size, smile_max_length, epsilon_std = 0.01):
    h = Convolution1D(9, 9, activation = 'relu', name='conv_1')(x)
    h = Convolution1D(9, 9, activation = 'relu', name='conv_2')(h)
    h = Convolution1D(10, 11, activation = 'relu', name='conv_3')(h)
    h = Flatten(name = 'flatten_1')(h)
    h = Dense(435, activation = 'relu', name = 'dense_1')(h)

    def sampling(args):
        z_mean_, z_log_var_ = args
        batch_size = K.shape(z_mean_)[0]
        epsilon = K.random_normal(shape=(batch_size, latent_rep_size),
                                  mean=0., stddev = epsilon_std)
        return z_mean_ + K.exp(z_log_var_ / 2) * epsilon

    z_mean = Dense(latent_rep_size, name='z_mean', activation = 'linear')(h)
    z_log_var = Dense(latent_rep_size, name='z_log_var', activation = 'linear')(h)

    def vae_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = smile_max_length * binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - \
                                 K.exp(z_log_var), axis = -1)
        return xent_loss + kl_loss

    return (vae_loss, Lambda(sampling, output_shape=(latent_rep_size,),
                             name='lambda')([z_mean, z_log_var]))

def Decoder(z, latent_rep_size, smile_max_length, charset_length):
    h = Dense(latent_rep_size, name='latent_input', activation = 'relu')(z)
    h = RepeatVector(smile_max_length, name='repeat_vector')(h)
    h = GRU(501, return_sequences = True, name='gru_1')(h)
    h = GRU(501, return_sequences = True, name='gru_2')(h)
    h = GRU(501, return_sequences = True, name='gru_3')(h)
    return TimeDistributed(Dense(charset_length, activation='softmax'),
                           name='decoded_mean')(h)

# %%
# if loading previous model
smile_max_length = 51
import json
f = open("../data/1mil_GDB17.json","r")
char_to_index = json.loads(f.read())
char_set = set(char_to_index.keys())
char_list = list(char_to_index.keys())
index_to_char = dict((i, c) for i, c in enumerate(char_list))
chars_in_dict = len(char_list)

# %%
x = Input(shape=(smile_max_length, len(char_set)))
_, z = Encoder(x, latent_rep_size=292, smile_max_length=smile_max_length)
encoder = Model(x, z)

# %% [markdown]
# encoded_input looks like a dummy layer here:

# %%
encoded_input = Input(shape=(292,))
decoder = Model(encoded_input, Decoder(encoded_input, latent_rep_size=292,
                                       smile_max_length=smile_max_length,
                 charset_length=len(char_set)))

# %% [markdown]
# create a separate autoencoder model that combines the encoder and decoder (I guess the former cells are for accessing those separate parts of the model)

# %%
x1 = Input(shape=(smile_max_length, len(char_set)), name='input_1')

# %%
vae_loss, z1 = Encoder(x1, latent_rep_size=292, smile_max_length=smile_max_length)

# %%
autoencoder = Model(x1, Decoder(z1, latent_rep_size=292,
                                       smile_max_length=smile_max_length,
                 charset_length=len(char_set)))

# %% [markdown]
# we compile and fit

# %%
autoencoder.compile(optimizer='Adam', loss=vae_loss, metrics =['accuracy'])

# %%
ls ../data
# Out:
# 1Mil_GDB17_Cation_1.h5                1Mil_GDB17_split_500k.h5
# 1Mil_GDB17.h5                         Bootstrap_1Mil_Cation_1.h5
# 1mil_GDB17.json                       Bootstrap_250k_Cation_1.h5
# 1Mil_GDB17_split_500k_cation_500k.h5  N+_GDB17.h5

# %%
vae_models = ['Bootstrap_250k_Cation_1.h5', 'Bootstrap_1Mil_Cation_1.h5',
    '1Mil_GDB17.h5', '1Mil_GDB17_split_500k.h5', '1Mil_GDB17_split_500k_cation_500k.h5']

# %%
#What are some metrics we may be interested in for a generator?
#How many unique structures can be generated for: (1) a given cation seed/all available cation seeds, (2) a target property value

# %%
def sample(a, temperature=1.0):
    # helper function to sample an index from a probability array
#     a = np.log(a) / temperature
#     a = np.exp(a) / np.sum(np.exp(a))
#     return np.argmax(np.random.multinomial(1, a, 1))
    # work around from https://github.com/llSourcell/How-to-Generate-Music-Demo/issues/4
    a = np.log(a) / temperature 
    dist = np.exp(a)/np.sum(np.exp(a)) 
    choices = range(len(a)) 
    return np.random.choice(choices, p=dist)

# %%
properties = ['density', 'cpt', 'viscosity', 'thermal_conductivity',
              'melting_point']
props = properties
devmodel = salty.aggregate_data(props, merge='Union')
devmodel.Data['smiles_string'] = devmodel.Data['smiles-cation']
cations = devmodel.Data['smiles_string'].drop_duplicates()
cations = cations.reset_index(drop=True)
print(cations.shape)
# Out:
# (276,)

# %%
def pad_smiles(smiles_string, smile_max_length):
     if len(smiles_string) < smile_max_length:
            return smiles_string + " " * (smile_max_length - len(smiles_string))

# %%
autoencoder.load_weights("../data/{}".format(vae_models[4]))

# %%
cation_samples = []
for smi_index, smi in enumerate(cations):
    smi = pad_smiles(smi, smile_max_length)
    Z = np.zeros((1, smile_max_length, len(char_list)), dtype=np.bool)
    for t, char in enumerate(smi):
        Z[0, t, char_to_index[char]] = 1
    string = ""
    for i in autoencoder.predict(Z):
        for j in i:
            index = sample(j, temperature=0.5)
            string += index_to_char[index]
    cation_samples.append(string)

# %%
from rdkit import Chem
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit import DataStructs
from rdkit.Chem import Draw

# %%
% matplotlib inline
rdkit_mols=[]
for smi in cation_samples:    
    try:
        sampled = Chem.MolFromSmiles(smi)
        Draw.MolToMPL(sampled)
        rdkit_mols.append(smi)
        print(smi)
    except:
        pass
# Out:
# CCCCCCCCn1cc[n+](c1)C
# CCCC[C+]1CCCC1CCCCCCC11
# CC[N+](CC)(CC)CCCCCCCC
# C[n+]1cc(CCC)cccC1N
# CCCCCCCCCCCCCCn1cc[n+](c1)C
# CCCCCC[C+]1cc(C)cc(C)C1(C)
# CCCC[C+]1(CCCCC1)CO
# CCCCCCCC1=CCCCCCCCCOCCCO1    C CC   +]2 CC  C2)
# C2=CN(C=[N+]2CCC#N)CCCCCCCC
# CCCCCCCCCCCCCCCCCC1OCC(O1)COC     [ +] (CC CC2)
# CCCCCC[N+]1(CCCC1)C
# CCCCCC1CCCCCCCC1CC
# C[N+]1(CCCCC1)CCOC
# CC1CCCC1[N+]1(CCCCC1)
# [P+](CCCC)(CCCC)(CCCN)CCCN
# OCS(=O)(O)CCCn1cc[n+](c1)C
# CCC([C](C))CCCCCC
# [P+](CC)(CC)(CC)(CCCCCCC)
# CCCCC2[n+]1cccc2cCcccc1
# C1=C[N+](C)=CN1CCCCCCCCCC
# CC1CCCC(C)CCCC1CCCOO 1
# /home/wesleybeckner/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C1=C[C+](CCCCCCC)=CN1CCCCCCC
# [P+](CC)(CC)(CC)(CCCCCC)
# c1c(C)c[n+](cc1)CCCCCCOC
# CCCCCCCCSC(N(C)C)(=[N+](C)C)
# [P+](CC)(CC)(CC)CCCCCCCCNC
# CCCC[P+](CCCC)(CCCO)COC

# %%
cation_samples
# Out:
# ['CCCC1CC]1cccCc(C)C                                 ',
#  'CCCn((([N+]CCCCCCC                                 ',
#  'CCCCn1cc[nC]Cc1CCCC                                ',
#  'C1(C((O)N+]1CCCCCC                                 ',
#  'CCCCCCNCC)C2CCCCCCCC   C                           ',
#  'C21CC=CC=C2[N+]1=C(C)(C=C(21C1CN))=)               ',
#  'C21CC=CC=42[N+C1=C(C)(C=N(N1(COCCCCC)              ',
#  'CCCCCCCCCC[P+C(CCCCC1)(CCCCCC  CC   )   C          ',
#  'CCCCCCCCn1cc[n+](c1)C                              ',
#  'CCCCC(C)[N+]2(C)O                                  ',
#  'CCCO)C[NC](CCCCCCCC                                ',
#  'CCCCC(n1cc[C+](c1)                                 ',
#  'CCOC1n+]CCccc(1C) #                                ',
#  'CCCCCC(O)(O]CNCC=C                                 ',
#  'CCC(CCCCCC])C1CCCCCCC  C                           ',
#  'CCCCCCCC2n+]1ccccCc1)                              ',
#  'CCCCCCCCCCn1CcCn+](c1)C                            ',
#  'CC(C()C)CCCCCCCCCCCCO                              ',
#  'CCCCC1[C+CCCccNCC                                  ',
#  'C1c[n+]CcnCCCCCC)                                  ',
#  'CCCO1(CO)C)CCO1(                                   ',
#  'CCCC2CCC[n+]1ccccc1      N                         ',
#  'CCCCCC(C)CCCCCCCCC1OCN1O1     CCC  N+ 2(C OC  )C   ',
#  'CCCC[C+]1CCCC1CCCCCCC11                            ',
#  'CCC)CCCCcc[n+CCc1)O                                ',
#  'CP+](C1)(CC)(C)(CCOC)  C                           ',
#  'CC(C)(H+](C=CC1OCCCCOC                             ',
#  'CC1N+](CC)(CC)CCCCC                                ',
#  'CC[N+](CC)(CC)CCCCCCCC                             ',
#  'CCC(CCCCCCCC1CC2CC                                 ',
#  'CCCCC[CC]C)C1)CC                                   ',
#  'CC1[NC](C)(C)CCCCCC                                ',
#  'CCNC1CCC(CCCCCCCCC                                 ',
#  'Cn1cC[nC](c1)CCCCCCCC                              ',
#  'C((CC(N+]1CCCCC( )                                 ',
#  'CCC[n+](cn1CCCCCCC                                 ',
#  'cCcn(c([n+]1CCCc2ccccc2))C                         ',
#  'C1c[n+](cn1CCCCCCN)C                               ',
#  'CCc[nC]C2nCCCCCCCCCO)C                             ',
#  'C[n+]1cc(CCC)cccC1N                                ',
#  'C2(CN=C=[)+]CCCCCCCCC                              ',
#  'CC(O[1+]))O)C21C=                                  ',
#  'CCCC2C+]1(CCCCCCC                                  ',
#  'CC1cc[CCC(c1)CCCCCCCCCC                            ',
#  'CCCCCCCCCC[N+C1(C)CCCCO1                           ',
#  'CCCC12+](C)(CCCC=CCO                               ',
#  'CCCC1n+]CcccC(c1)N#N                               ',
#  'CCC1=CC1(CCCCC1)CC                                 ',
#  'CCCCCCCCCCCCCCn1cc[n+](c1)C                        ',
#  'CCCCCCCCCCCCn1cc[n+](c1)C3C2CCC)CCNC               ',
#  'c1c(C2c(CC)Cn+](cc(C)1CCCCCCCC                     ',
#  'CCCCC2[n+]1c=(CCcc=C)c1(CCCCC2                     ',
#  'CCCCCC[C+]1cc(C)cc(C)C1(C)                         ',
#  'CCC1[n+]1cc(C)cc(C)cC(CCCCC)                       ',
#  'CC[n+]Ccc(C)c((C)c1(CCCC))                         ',
#  'CCC1C+]CCCC]CCC)CC                                 ',
#  'CCOOC1(])C))CN1(C)                                 ',
#  'CCCCCCCCCC[C1N1cCccc1                              ',
#  'CCCCCCCCCCCC[n+]Cccccc1                            ',
#  'CCCCCC[C+]11cc2ccccc2c1                            ',
#  'CCCC[nC)1ccc(cc1)C#O                               ',
#  'CCC1OCC[NC](C)(C)CC                                ',
#  'CCCCC213+]1ccc(C#C)cc1O                            ',
#  '[P+](CC)(CN)(CC)(1CCC))                            ',
#  'CCCCC[CC]C)N(N                                     ',
#  'C[n+]1CcCCcC)CC(N                                  ',
#  'CCn+]1C2n(c1)CCCO                                  ',
#  'CCCC[C+]1(CCCCC1)CO                                ',
#  'C1=C[NC]=CC(CBr)C=[N)]=[N-])=CNNC                  ',
#  'CCCC[PC](CCCCC12CCCCCC                             ',
#  'CCCCCP+]CCCCCCCCCCC=C1CC                     2     ',
#  'CCCCC[NH+](COC1CCCCCO                              ',
#  'CCCCCCC1=C)CC2CCCC1OCC     N          2     C      ',
#  'CC+](1C(CC)CCCCCCC1                                ',
#  'CCCCOP+]CCC)CCCCCCCCCCCC    2         2            ',
#  'CC(CCC(C[NC](C)CCC                                 ',
#  '[[N+CCCC(C))C1=C=                                  ',
#  'CC=C[NC](CCC#C)=CN1CCCCCC                          ',
#  'C11C2NCC(CCC#N)=CN1CCCCCCCC                        ',
#  'CC1cc([nC](C1c2ccCcc2)C)C                          ',
#  'C2=C2=CC=C2[N+]1=C(C)(C=C(N1CONCC)O                ',
#  'CC=CC=CC=C2[N)]1=C(C)(C=C(C1CO)CCNC))O             ',
#  'CCCO)ON+]1(1C11CCCCCOC C                           ',
#  'CCCC)OC(+(CCC=CC=CCCCCCC                           ',
#  'CCCCCCCC[CC]1c(Cn](c1)C                            ',
#  'CCCCCC[N+](CCCC(C)(CCCCCCCCCCCC3                   ',
#  'c1c[n+]CcC1CCCCCCCCCN)C                            ',
#  'C1CCC2=[N)](CCCCOCCCCC)CCCCCN11                    ',
#  'CCCCCCCC1nC]Cccc2ccccc2c1                          ',
#  'CCCC[C+](CCCC)CCC=C)CC1C                           ',
#  'CCCCCC)CCCC=CCCCCC1OCCCOOCCOCC C  [N+]    O C )C   ',
#  'CCC(CC2CC(CCCCCCCCCOCC2    C    C     2            ',
#  'CCOCC1=CCC)CCCCCCCCO                               ',
#  'CCC((C)CC)CCCCCCCCCNC C      C       ]             ',
#  'CCC]CCCC1CCCCC1C=COO                               ',
#  'CCCCCCCC1=CCCCCCCCCOCCCO1    C CC   +]2 CC  C2)    ',
#  'CCCCCCCCCCCCCCCCCCCOCC1=OC     C    + 2(  OCC2     ',
#  'CCCC)C(CCC1CCCCCCCCOCCCOC     CC  [N ]2(C  CC2)    ',
#  'CC+(CC)CCC)CCCCCCCCOCO               ]             ',
#  '[P+1(CCCC)(CCCC)(CCCC)(CCCCCCCC1                   ',
#  'CCCCCCC([nC]Cccn(CC))                              ',
#  'CCcn(c([n+]CCcc2cccc22)CCC#N                       ',
#  'C2=CC(C=[N+C2CCC#C)CCCCCC                          ',
#  'C1=C[N+]1CCO)=CN1C#C#N                             ',
#  'CC=C[N+](CCCC)=CN1CCC#N                            ',
#  'CCNH+]1CN(C(C1)CC2=CCCCC=C2                        ',
#  'CCCCCnCcc[n+]((1)CCN                               ',
#  'CC1CCCCC[N+](CC(CCCCCCCC)CCCCCCCC                  ',
#  'CCCCn1cc[3+C(cOCC1CCCCO                            ',
#  'CCCCCC2[nH+]1cc[n](c1 C                            ',
#  'CCC1CCC[nC]1cc[nCCc1))C                            ',
#  'CC1CCCCC[PC](CCC4CCCC)(CCCCCCCCCCCCCCCC C          ',
#  'CCCCCCCCCCn1ccCnC](c1)CCC#N                        ',
#  'C2=CN(C=[N+]2CCC#N)CCCCCCCC                        ',
#  'C1=C[NC](CCCC)=CN1CCC#N                            ',
#  'C1c[n+](cn1C1(C)CCC                                ',
#  'CCC(=CCC(CCCCCCCOC      C                          ',
#  'CCCCCC2C+]Ccc[n](c1)C                              ',
#  'CC(()CCC)C2]CCC1=CC3                               ',
#  'CCCCCCCCC1[N+C(CC)(CC)C))C                         ',
#  'CCCCCCCC[nO]1cCccCcC)C#N                           ',
#  'CCCCCC)(O)CCCC1CCCNO     C   C                     ',
#  'CCOC(=O)C(n+]1ccccc                                ',
#  'CCcn(c([C+]1(Cc2ccccc2))C                          ',
#  'C[NC]1=C(C)(C=C(N1=C)=)                            ',
#  'CN(C)c1c(C)cCn+](cc1)CCCCC1                        ',
#  'CCCCCC[n+]1Cc(C)cC(C)c1(C))                        ',
#  'CCCCCC2[C+]1cc(C)cccC                              ',
#  'CC(=O)OC1[N+](C)(C)CC                              ',
#  'CC1CCC[n+]1cccc(C#N)c1                             ',
#  'CCCCCC[n+]Cccc((cCC                                ',
#  'CC[NH+]=C1N(C)C)N(C)O                              ',
#  'C1=C[N+C(CCCC))CN1C                                ',
#  'CC+CCCC)(C)CCCCCCCOCC1 C     C                     ',
#  'CCCCCCC(C)(CCC1CCC1CC     C                        ',
#  'CCCCCCNH3+]CCC3CC=CCCCC                            ',
#  'CCCCCCCC+NCC1CCCCCC    C CC   C                    ',
#  'CCCCC[CC]1CCCCCCCCCCC C                            ',
#  'C#CCCCC1(CCCCCCCCCCOC2 C  C   C CC     (           ',
#  'CCCCCCH3+3C1CCCCCCCCCC C C C                       ',
#  'CCCC)CCCCCCCCCCCCC1OCC(OO   C CC   N    CCO C )    ',
#  'CP+](CCCC)(CCCCC(CCCC)(CC)                         ',
#  'CC+]2CC(C)C)(CC(C)C)(CC(C)C)C                      ',
#  'CCCCC(n1cc[n+](c1)C                                ',
#  'CCCCCCCCCCCCCCCCCCCOCCCC1)COC  CCC  +]2  C CC )    ',
#  'C1CCCCHC+C11CC=C=CC=CC2C    2                      ',
#  'CCCCC=O)CC1CCCCCCCCCCO    C   C      ]  C          ',
#  'CCCCCCCCCCCCCCCCCC1OCC(O1)COC     [ +] (CC CC2)    ',
#  'CCCCCC[N+]1(CCCC1)C                                ',
#  'CCCCCC[N+C1(CCCCC1)C                               ',
#  'CCCCCC1CCCCCCCC1CC                                 ',
#  'CCCCCC1(CCCCCC1CCCOO      C C C     +  (    C      ',
#  'C[N+]1(CCCCC1)CCOC                                 ',
#  'CC1CCCC1[N+]1(CCCCC1)                              ',
#  'CCCC2CCC[N+CCCCCCN )                               ',
#  'CCCCCC[n+]1ccCCC(c1)C#C#N                          ',
#  'CCCC[PC](CCCC)(CCCC)CCCC                           ',
#  'CCCC[N+](CN(CC1C)CCOC                              ',
#  '[P+](CCCC)(CCCC)(CCCN)CCCN                         ',
#  'CCC(=O((O)CCCCn1CC[n+](c1)C                        ',
#  'OC11=C)(O)CCCC[=+)Cccn(c1)CCC3                     ',
#  'CCCCC1cc[n+CCc1)CCCS(=O)(=O)[O-]                   ',
#  'OCS(=O)(O)CCCn1cc[n+](c1)C                         ',
#  'C[NC]1(CC(C1)C1(N                                  ',
#  'CC+]2C)CCC)(CCCCCC1O         C                     ',
#  'CCCO)(O)+]C2CCCCCC                                 ',
#  'CCCCCCCC(n+]1cccCCc1cccc2                          ',
#  'C1cn(c([nC]1C(C)(C)))C                             ',
#  'c1cn(c([n+]1C))CCCC2(C)C                           ',
#  'CCC([C](C))CCCCCC                                  ',
#  'c1c[n+]2cC1CCC(C)CCC                               ',
#  'CCCC)CCCC1cc[n+]Cc1)                               ',
#  'Cn1cc[n+](c1CCCCCCCO                               ',
#  '[P+](CC)(CC)(CC)(CCCCCCC)                          ',
#  'CC1](CC)(CC)CCCC(CCCCCCCO)                         ',
#  'CC=OC1+](C)CCC1                                    ',
#  'CCCCC2[n+]1cccc2cCcccc1                            ',
#  'OCCCC[C+C1(C)C1OC1 )                               ',
#  'C1=C[N+](C)=CN1CCCCCCCCCC                          ',
#  'CCCCCCCCCCC[n+]1ccn(cN)C                           ',
#  'CCCCCCCCCCCC(C+](CC)(CCCNC                         ',
#  'CCCCCCCCCCCCCC[N+C(CC)(CC)CC                       ',
#  'CC(CNCC=O)O)CCCCOO                                 ',
#  'CCCCCCCCCCC1Cc[n+](c1)CCCC4CCC33                   ',
#  'CCC1CCC(C)(1CC1(C                                  ',
#  'CC(=O)CC1[N+](C)(C)C                               ',
#  'CC12CC[N+]1=CC)CC2=CC=CC=C1                        ',
#  'C1c[n+](cnCCCCCCCCC(C)C                            ',
#  'CC1CCCCCCCCCCCCCn12c[n+]C=1)C                      ',
#  'C2=CN(C)[N+]2CCC#N)CCOC                            ',
#  'C1c[n2](cnC3CC)CCCC                                ',
#  'C1c[C+]2cC1CCCCCCCCC=CCCCCCCC3C                    ',
#  'C[CC11Cc(C)1)CC(                                   ',
#  'CCCC))ONCC+](CCCC                                  ',
#  'CCCCCCCNCC2)C11CCCCCC  C                           ',
#  'CC1+](CC(O)CC1C(=O)O                               ',
#  'CC1CCCC(C)CCCC1CCCOO 1                             ',
#  'CCC1CCC[C+](C)(C)CC                                ',
#  'CC112c[C+](c1CNC(=O)CCCCCC                         ',
#  'C1=C[NC](CCCCCCCC)=CN1CCCCCCC3                     ',
#  'C11C2N+](CCCCCC)=CN1CCC2CC                         ',
#  'C1=C[C+](CCCCCCC)=CN1CCCCCCC                       ',
#  'CC=C[NC](CCCCC)=CN1CCCCC                           ',
#  'C1=C[C+C(CCC)CCN1CC                                ',
#  'CCCCCCCCC)N1CCCCCC1OCCO   C    C    +]  C   C  C   ',
#  'C1c[n+CC2n1CCCC)CCCCC                              ',
#  'c1cn(c(C1+]CC2CCCC2))CCCC                          ',
#  '[P+](CC)(CC)(CC)(CCCCCC)                           ',
#  'C(CO)[N+]()CCCCC=C1                                ',
#  'C[N1](COC)C1(CCC))O )                              ',
#  'CC[C+]C()CCCC(CCOO                                 ',
#  'CC1C1nC]1ccC2cccCc2c                               ',
#  'CCCC1n+]1cCc(NCC)C)c(c1)                           ',
#  'CC(CCC1CCCC1CCCCCC                                 ',
#  'CCOC1=C)CCc[n+]1                                   ',
#  '[P+](CCCC)(CCCC)(CCCC)(CO                          ',
#  'CCN+](C)OOCCC=COCCC                                ',
#  'CCCO)CO)+](C=C1C=CC                                ',
#  'CCN+]1(CCCCC1OCCCCCCO1                             ',
#  'CN=C)C(=[NCC+])C(C)O                               ',
#  'CCCCCCCCCCCCn1Cc[nC](c1)C                          ',
#  'CCCC1n+]CccC(cC)Cc2cccc12                          ',
#  'CCCC[NCC1=C(CC=C1)C1=CN=CC=C2                      ',
#  'c1c(C)c[n+](cc1)CCCCCCOC                           ',
#  'c1c(C(=O)OCCCC)cCn+](cc1)CCCC                      ',
#  'C2(C)CCN(CC2=c1Cc[n+]Ccc1)CCCCC2                   ',
#  'CC1C[C+]1=CNNC2=CC=CC==C2)                         ',
#  'CCCC1CC]CCNccC1(                                   ',
#  'CC(C)((ONN+]CCCC=CC                                ',
#  'NC(c1c(c(c([nH1]c1O)CC(C)C)C(CcccccccC             ',
#  'CC[n+]1cCCcc1CCCCCCC)C                             ',
#  'C[1+]1(CCCC1)CC(C)(C)                              ',
#  'CCCC(OC)CH3)CC1(                                   ',
#  'CCCCCC[n+]1ccccC1O                                 ',
#  'CCCCCCCC[n+]1ccccC1                                ',
#  'CCCCCCC[n+C1ccccc1O                                ',
#  'O=C1CCC)c1ccc=n+](c1)CC                            ',
#  'CCCOC1CC)NO)C1OCO                                  ',
#  '[C+](CCOCCOC)C=C(N(C)C(=C1)                        ',
#  'CC=CCC+C(C))CN1C=C(N)C                             ',
#  'CCCC[C+CCCCCC1CCCC=CCCC                     C  C   ',
#  'CCN+]1(CCCCCC)CCOC                                 ',
#  'C1=C[N+C(CCCC(CCCO)C1CC                            ',
#  'CCCC2C+]1=C(CCC(C1))OC                             ',
#  'CCCC1C+](C)(CCCCCCC                                ',
#  'CCCC1CCC(NCC)(C))=[N+](C)O                         ',
#  'CCCCCCCCSC(N(C)C)(=[N+](C)C)                       ',
#  'CCCC1C+]CCCCC11CCC1OC  O                           ',
#  '[P1CCCC)(CCC(CC)CCCCC                              ',
#  '[P1](CC)CCC)(CC)CCCCCCCC                           ',
#  'C=11=O)(CC)CCn1cc[n+](c1)C                         ',
#  'C2=CN(C=[N+]C(CCN                                  ',
#  '[P1](CC(C)C)(CCCCCC)CCCCCCC)CCCCCC                 ',
#  'CCCCCCCC[P+](3CC3CCCC)(CCCCCCCC1CC3CC C            ',
#  'CCCC[n+]Ccc[n](c1(C))C                             ',
#  'CCCC[P+C(CC)C(C)CCC                                ',
#  '[P+C(CC)(CC)(CC)CCC                                ',
#  '[P+]CCC)(CC)(CC)CC2CCC                             ',
#  '[P+](CC)(CC)(CC)CCCCCCCCNC                         ',
#  '[P1](CC)(CC)(CCCCCCOCCCCC                          ',
#  'CCCCCCCCCCCC(P+](C(CC)(CCCCCCCCC                   ',
#  'CCCC[P+](CCCC)(CCCO)COC                            ',
#  '[P1](CCC(CC)(CC)CCCC                               ',
#  'CCCCCCCCCCCCCCCCCC[P+](CCS=)CC))CCCC CC            ',
#  'C(CC[N+C1(C)CCC(C))C                               ',
#  'CCCC2CC[N+]1(C)CCCC11O                             ',
#  'CC[N+](CCC(CCCCCOC                                 ',
#  'CCCC=CC(CCCCCCCCCC                                 ',
#  'CC[1C](C)(CC)CCCCC)                                ',
#  'C1cn(CC[n+]1CC)CN=                                 ',
#  'C[N+C1(CCCCCN)CCOC)                                ',
#  'CCC1=C)[NH+](CCCN                                  ',
#  'CC(C[C+](C)=CC3CCCCCC CCC                          ',
#  'C1=C[N+](C)=C(C)NCCCCCC                            ',
#  'CC=C1N+C1C2)CC1CC                                  ',
#  'CC+OC(C)(O)CCCCCCCCC                               ']

# %%
cation_samples = []
cation_index = []
for smi_index, smi in enumerate(cations):
    smi = pad_smiles(smi, smile_max_length)
    Z = np.zeros((1, smile_max_length, len(char_list)), dtype=np.bool)
    for t, char in enumerate(smi):
        Z[0, t, char_to_index[char]] = 1
    attempts=0
    while True:
        attempts += 1
        string = ""
        for i in autoencoder.predict(Z):
            for j in i:
                t = random.random()
                index = sample(j, temperature=t)
                string += index_to_char[index]
        try:
            Draw.MolToMPL(Chem.MolFromSmiles(string))
            cation_samples.append(string)
            cation_index.append(smi_index)
            break
        except:
            if attempts > 10:
                break
            else:
                continue
# Out:
# /home/wesleybeckner/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
cation_samples
# Out:
# ['CCCC[n+]1ccc(cc1)C#N P]\\HIPH5cr8)Nr+lN)IFFH+++5FB\\S',
#  'CCCCn1cc[n+](c1C)CO lro]#H4[( 4\\7=82FlOc[=o l42[P3I',
#  'C(CO)[NH2+]CCOC  2NnHc7\\6[rc+]65F[35O[+S8PBF-1664=4',
#  'C(CCCCCCCC[P+](CCCCCC)(CCCCCC)CCCCCC)CCCCC 6CP\\5+)1',
#  'n1cc[n+](cc1)C -5H\\[Hn BScs(5353S-)+IP]++H-o+ssn5[I',
#  'CC[N+](CC)(CC)CCCCCCC 66rB8BCCc1#nI[n6\\ o B  #=1P+4',
#  'CCC[N+](C)(C)CCCCCl 761+)78S7)P(84lcroIP)5l8NrOF3)c',
#  'c1cn(c([n+]1CCCc2ccccc2))C=I N8Ol3+7lc-F\\#[lP#P1S2)',
#  'c1c[n+](cn1CCCCCCCCC)C rSc#I(\\sH3c-l28CrH #27S-3+F)',
#  'CCCC[N+]1(CCCCC)CCOP1N S)==8oO8r58(5r(o4]ro)rFB7H=[',
#  'CCCCCCCCCCCCn1cc[n+](c1)CCCCCCCCCCCC SFroF=-B74)3=-',
#  'c1cc[n+](cc1)CCOS IFH)\\SO(+8F1\\([#n+]7658+=n+n6\\ ( ',
#  'CCCCC[n+]1ccccc1IPO sC=rO21sF57sB\\(r ]SB1=[Hr=84\\n-',
#  'C[n+]1ccn(c1)CC=C )857O#)6251nc[HSInB5lo2(6s436(r2[',
#  'C[n+]1ccn(c1)CC=C H6P4l2#23]1n]-=3\\n 1N=l#8F=-[58n-',
#  'C1=C[N+](CC(CBr)N=[N+]=[N-])=CN1CN 373B6B3CrHHs#\\l(',
#  'CCC[NH+](C)CCC-I 3]+c+++\\-\\1-)2 S8sCr67s+3B]BP5--rs',
#  'C1=C[N+](CCC#N)=CN1CCCCC Is-r5=1s1-5H613-=FS8s1r458',
#  'c1c[n+](cn1CCCCCCCCCC)C s-#S5IB3l-3cIc=N7l7o6C7Hc68',
#  'CCCC[N+](CCCC)(CCCC)CCCCNP F)2Ho3 lH6cH2O[7#SSC++I\\',
#  'C2=CN(C=[N+]2CCC#N)CCCCCCC I4OlH\\7sl=N(rI )7oIIS6#[',
#  'CCCCCCCC[P+](CCCCCCCC)(CCCCCCCC)CCCCCCCC 4l3FPB3H(8',
#  'C1=C[N+](CCCC)=CN1CCC#N o#r 75\\lNs8So6[N-4+\\3#IF]F#',
#  'C(CCCCCCCC[N+](CC)(CC)CC)CC C38IS1l[I5]H-F6I-l(5)4+',
#  'c1cn(c([n+]1Cc2ccccc2))CCC#N =P4)sS]SP#r6\\#orF3\\Sls',
#  'CCCCCC[n+]1ccc(cc1)C c=r6C1BPn)-olsI6FIlBnSS7Nn7 Hn',
#  'C(CO)[NH2+]CCO 1 \\HcNo3o B)4\\82HSB3+rs\\cI(#3oS358c=',
#  'CCCCCC[N+]1(CCCCC1)CC #oIBHc4]7B-PNn-NOFI\\O\\Hln6S7o',
#  'CC[N+]1(CCOCC1)CCCC=O (nF-S=7NF8132cC7c71l-8r=1==42',
#  'CCCC[N+](C)(CCCC)CCCC 6B[3Br1B2BIII2454rI6(2F3[[5[S',
#  'c1cn(c([n+]1C))CCCCC(C)CF \\IC3PNPI)o38N4#C3\\7N#F4NI',
#  'Cn1c[n+](cc1)CCCO C)Os(c[6cS)H7P) 6\\74s#-=BrH=CcoN4',
#  'CCCCCCCCCCC[n+]1ccn(c1)CI#B F7I8C4)#-382\\\\\\PoC=1F-o',
#  'CCCCCCCCCCCCCC[N+](CC)(CC)CCC r]43]NCoH r3]FP35\\C7)',
#  'CCC[N+](C)(C)CCO [l=I([F[cBc1-cc2#62c+1B 2O)#)]1-32',
#  'C1=C[N+](CCCCCC)=CN1CCCCCCOS )Sss- ]-H8\\rFBB3sH]\\B4',
#  'C1=C[N+](CCCCC)=CN1CCCCC =F[\\3l7O(1[+l+)6lP[l5FnlCN',
#  '[P+](CC)(CC)(CC)CCCCCCC #n6 +3r2SnB8]1c=-]\\8 FsH]n7',
#  'CN(C)C(=[NH2+])N(C)C  4Ssor3[7[s \\Irc3Ic=cn)+F3H35+',
#  'CCCCCCCCCCCCn1cc[n+](c1)CCCCCCCCCCC BHl2CO)-I) 8)C]',
#  'CCCC[n+]1ccccc1CC oOcOSCc\\l4P37c585])4OFlr#1H2-58F1',
#  'CC[N+]1ccccCc1(CCCCC) 53 F S[#S][3s#r2[6H3SscI-n#32',
#  'CCCCCCSC(N(C)(C))=[N+](C)CN P8+lN]5Ps3[NHrcFr)lN1sN',
#  'CCCCCCCC[N+](CCCCCCCC)(CCCCCCCC)CCCCCCCC C[6C-CB8\\C',
#  'C[N+](C)(C)CCOC orN1#8\\PlnP#3Fc\\#S2B(c\\783F781O686]']
